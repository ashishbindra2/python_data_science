# %% [markdown]
# ### Accessing databases using Python

# %% [markdown]
# ![db1.PNG](attachment:db1.PNG)

# %% [markdown]
# ### Waht is SQL API
# ![sql_api.PNG](attachment:sql_api.PNG)

# %% [markdown]
# ### Concepts of the Python DB API
#
# 1. Connections Objects
# 2. Cursor Objects
#
# - Connection Objects
#     - Database Connection
#     - Manage transactions
# - Cursor object
#     - Database query (run querres)

# %% [markdown]
# ###
# ![dbapi.PNG](attachment:dbapi.PNG)

# %% [markdown]
# ### What are Connection methods?
# - cursor(): return a new cursor object using connection.
# - commit(): commit any pending transactions to database.
# - rollback(): caueses the database to rollback to start of any pending transcation.
# - close(): Clise a database connection.

# %% [markdown]
# ### Writeing code using DB-API
# use the db api to query a database

# %%
from dmodule import connect

# Create connection object
connection = connect("databasename", "usename", "pswd")

# Create a connection object
cursor = connection.cousor()

## Run queries
coursor.execute("select * from mytable")
results = cursor.fetchall()

# Free resources
cursor.close()
connection.close()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from dmodule import connect
#
# ModuleNotFoundError: No module named 'dmodule'

# %% [markdown]
# #### NOTE: Always important to close connections to avoid unused connections taking up resources.

# %% [markdown]
# #### Using the info() Method gives an overview of the top and bottom 30 rows of the DataFrame, useful for quick visual inspection

# %% [markdown]
# #### Some statistical metrics may return "NaN," indicating missing values, and the program can’t calculate statistics for that specific data type.
