# %% [markdown]
# ### Correlation
# Correlation is asstatistical metrix for measuring to what extent different variables are interdependent
# - if one variable changes, How does this affect change in other vaiable>
# - for eg
#     - Lung cancer => smoking
#     - Rain => Umbrella
# - Correlation doesnot imply causation

# %%
sns.regplot(x="engine-size", y="price", data=df)
plt.tlim(0,)

# %% [markdown]
# ### Positive corelation
# ![postive%20corelation.PNG](attachment:postive%20corelation.PNG)

# %% [markdown]
# ## Negative corelation
# ![negative%20correlation.PNG](attachment:negative%20correlation.PNG)

# %% [markdown]
# # Week corelation
# ![week%20corelation.PNG](attachment:week%20corelation.PNG)

# %% [markdown]
# ### ![pearson%20corealtion.PNG](attachment:pearson%20corealtion.PNG)

# %%
pearson_coef, p_value = stats.pearsonr(df["horsepower"], df["price"])

# Pearson correlation: 0.81
# P-vakue: 9.35 e-48

# %% [markdown]
# ![cooreation%20heatmap.PNG](attachment:cooreation%20heatmap.PNG)

# %%
dignal that re dark red color indicate that all valuea on this dignal are higly corelated
