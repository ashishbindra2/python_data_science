# %% [markdown]
# ### How to Opening a File

# %%
import pymupdf

doc = pymupdf.open("file/page_1.pdf") # open a document

# %% [markdown]
# ### Extract text from a PDF

# %%
print(doc)
# Out:
# Document('file/page_1.pdf')

# %%
for page in doc: # iterate the document pages
    text = page.get_text()
    print(text)
# Out:
# Aled
# So
# Real
# estate
# ae)
# Urban Real Estate BV
# Schippersstraat 21
# 3500
# Hasselt
# BTW
# : BEQ881.675.560
# ml
# @
# ~~
# @
# FACTUUR
# Nr. 20103
# Datum
# 02/06/2020
# o——-
# OMSCHRUVING
# Vergoeding
# project Willebroek
# - Dendermondsesteenweg
# ingevolge overeenkomst
# dd. 02/06/2020.
# Totale
# verkoopprijs 13 appartementen:
# 3.218.000,00
# Totale
# vergoeding: 4%
# 128.720,00
# Verschuldigd bij ondertekening
# overeenkomst: 1.5%
# 3.218.000,00
# 48.270,00
# Saldo MVH
# 48.270,00
# BTW
# 21%
# 10,.136,70
# Totaal
# 58.406,70
# U
# wordt
# verzocht het
# vermelde
# bedrag binnen 10
# dagen
# over
# te maken
# op
# het onderstaande rekeningnummer.
# EIk niet op
# de
# vervaldag betaald bedrag
# zal van rechtswege
# en zonder
# ingebrekestelling worden
# verhoogd
# met
# een
# interest van 7%
# per jaar
# en een
# forfaitaire schadevergoeding
# van 15%
# met
# een
# minimum
# van EUR
# 100,00.
# Omtrent
# welk
# geschil ook
# zijn enkel de Rechtbanken
# van Antwerpen,
# ...

# %%
for page in doc: # iterate the document pages
    print(page)
# Out:
# page 0 of file/page_1.pdf

# %% [markdown]
# ### document contains image based text content the use OCR o

# %%
import pymupdf

doc = pymupdf.open("file/image based text.pdf")

# %%
for page in doc:
    tp = page.get_textpage_ocr()
    text = page.get_text(textpage=tp)
    print(text)
# Out:
# Adselut
# Beekheuden
# CODA
# apy
# ag
# © Wolte rs K |uUWe r
# taasoftware.wolterskluwer.be
# Ae
# @
# »
# »
# 6*
# e
# @pa
# @
#
# |
# Verwerking in ACGSOIUt.................cccceccsececccecceccceccsccececnscscssesseusecesteuecascassasscasctassacctsssesssssccssserseaed.
# Inhoudsopgave
# Boekhouding — CODA
# 1
# 11
#
# seseseees
# ignores aaa
# =
# t
# '
# a eae ARTS TT
# RE TET SS SS
# TD
# 2
# CODA staat voor gecodeerd dagafschrift. Reeds jaren hebben de banken een standaard die interbancair
# vastgelegd werd. Wat CODA betreft bestaan er veel versies, om een optimale werking binnen adsolut te
# hebben heb je een full CODA nodig (laatste versie).
# De CODA worden aangeleverd door de banken. Dan kan je via de individuele programma’s van de bank de
# bestanden downloaden. Ofwel kunnen wij ervoor zorgen dat alle CODA bestanden dagelijks aangeleverd
# worden. Wij brengen dan alle formaliteiten bij de bank in orde. Als je hier meer informatie over wenst stuur je
# ...

# %%
! pip install -U pymupdf4llm
# Out:
# ...
#   Obtaining dependency information for pymupdf4llm from https://files.pythonhosted.org/packages/f7/21/9d31f47dbb8646b89f934a58a2f95a51671d691a7a46f3c9e71a3b2bf874/pymupdf4llm-0.0.10-py3-none-any.whl.metadata
# ...

# %%
# convert the document to markdown
import pymupdf4llm
md_text = pymupdf4llm.to_markdown("file/image based text.pdf")

# Write the text to some file in UTF8-encoding
import pathlib
pathlib.Path("output.md").write_bytes(md_text.encode())
# Out:
# 21

# %%
import pymupdf

doc = pymupdf.open("textImgecolorPDF.pdf")
for page in doc:
    text_blocks = page.get_text("dict", flags=pymupdf.TEXTFLAGS_TEXT)["blocks"]
    for block in text_blocks:
        for line in block["lines"]:
            for span in line["spans"]:
                text = span["text"]
                color = pymupdf.sRGB_to_rgb(span["color"])
                print(f"Text: {text}, Color: {color}")
# Out:
# Text: Lorem , Color: (0, 0, 0)
# Text: ipsum , Color: (0, 0, 0)
# Text: dolor , Color: (0, 0, 0)
# Text: sit , Color: (0, 0, 0)
# Text: amet,, Color: (0, 0, 0)
# Text: consectetur , Color: (0, 0, 0)
# Text: adipisici , Color: (0, 0, 0)
# Text: elit, , Color: (0, 0, 0)
# Text: sed, Color: (0, 0, 0)
# Text: eiusmod tempor incidunt ut labore, Color: (0, 0, 0)
# Text: et dolore magna aliqua. Ut enim ad, Color: (0, 0, 0)
# Text: minim , Color: (0, 0, 0)
# Text: veniam, , Color: (0, 0, 0)
# Text: quis , Color: (0, 0, 0)
# Text: nostrud, Color: (0, 0, 0)
# Text: exercitation , Color: (0, 0, 0)
# Text: ullamco , Color: (0, 0, 0)
# Text: laboris, Color: (0, 0, 0)
# Text:  nisi ut, Color: (0, 0, 0)
# Text: aliquid ex ea commodi consequat., Color: (0, 0, 0)
# Text: Quis aute iure , Color: (0, 0, 0)
# Text: reprehenderit, Color: (255, 0, 0)
# Text:  in, Color: (0, 0, 0)
# Text: voluptate, Color: (0, 128, 0)
# Text:  velit esse cillum dolore, Color: (0, 0, 0)
# ...

# %% [markdown]
# ### Extract images from a PDF

# %%
import pymupdf

doc = pymupdf.open("file/page_3.pdf") # open a document

for page_index in range(len(doc)): # iterate over pdf pages
    page = doc[page_index] # get the page
    image_list = page.get_images()

    # print the number of images found on the page
    if image_list:
        print(f"Found {len(image_list)} images on page {page_index}")
    else:
        print("No images found on page", page_index)

    for image_index, img in enumerate(image_list, start=1): # enumerate the image list
        xref = img[0] # get the XREF of the image
        pix = pymupdf.Pixmap(doc, xref) # create a Pixmap

        if pix.n - pix.alpha > 3: # CMYK: convert to RGB first
            pix = pymupdf.Pixmap(pymupdf.csRGB, pix)

        pix.save("page_%s-image_%s.png" % (page_index, image_index)) # save the image as png
        pix = None
# Out:
# Found 1 images on page 0

# %%
import pymupdf
doc = pymupdf.open("file/Holidays.docx")
page = doc[0]
paths = page.get_drawings()  # extract existing drawings
# this is a list of "paths", which can directly be drawn again using Shape
# -------------------------------------------------------------------------
#
# define some output page with the same dimensions
outpdf = pymupdf.open()
outpage = outpdf.new_page(width=page.rect.width, height=page.rect.height)
shape = outpage.new_shape()  # make a drawing canvas for the output page
# --------------------------------------
# loop through the paths and draw them
# --------------------------------------
print(paths)
for path in paths:
    # ------------------------------------
    # draw each entry of the 'items' list
    # ------------------------------------
    for item in path["items"]:  # these are the draw commands
        if item[0] == "l":  # line
            shape.draw_line(item[1], item[2])
        elif item[0] == "re":  # rectangle
            shape.draw_rect(item[1])
        elif item[0] == "qu":  # quad
            shape.draw_quad(item[1])
        elif item[0] == "c":  # curve
            shape.draw_bezier(item[1], item[2], item[3], item[4])
        else:
            raise ValueError("unhandled drawing", item)
    # ------------------------------------------------------
    # all items are drawn, now apply the common properties
    # to finish the path
    # ------------------------------------------------------
    shape.finish(
        fill=path["fill"],  # fill color
        color=path["color"],  # line color
        dashes=path["dashes"],  # line dashing
        even_odd=path.get("even_odd", True),  # control color of overlaps
        closePath=path["closePath"],  # whether to connect last and first point
        lineJoin=path["lineJoin"],  # how line joins should look like
        lineCap=max(path["lineCap"]),  # how line ends should look like
        width=path["width"],  # line width
        stroke_opacity=path.get("stroke_opacity", 1),  # same value for both
        fill_opacity=path.get("fill_opacity", 1),  # opacity parameters
        )
# all paths processed - commit the shape to its page
shape.commit()
outpdf.save("drawings-page-0.pdf")
print("done")
# Out:
# []
# done

# %%
import pymupdf
from pprint import pprint

doc = pymupdf.open("file/Holidays.pdf") # open document
page = doc[0] # get the 1st page of the document
tabs = page.find_tables() # locate and extract any tables on page
print(f"{len(tabs.tables)} found on {page}") # display number of found tables

if tabs.tables:  # at least one table found?
   pprint(tabs[0].extract())  # print content of first table
# Out:
# 1 found on page 0 of file/Holidays.pdf
# [['LIST OF HOLIDAYS - 2024', None, None, None],
#  ['', 'HOLDAYS', 'DAY', 'DATE'],
#  ['1', 'New year', 'Monday', '01st January'],
#  ['2', 'Republic Day', 'Friday', '26th January'],
#  ['3', 'Holi', 'Monday', '25th March'],
#  ['4', 'Good Friday', 'Friday', '29th March'],
#  ['5', 'Id-ul-Fitr', 'Thursday', '11th April'],
#  ['6', 'Buddha Purnima', 'Thursday', '23rd May (or)'],
#  [None, 'Bakrid/Eid ul-Adha', 'Monday', '17th June'],
#  ['7', 'Indepandence Day', 'Thursday', '15th August'],
#  ['8', 'Rakshabandan', 'Monday', '19th August'],
#  ['9', 'Krishna Janmashtami', 'Monday', '26th August (or)'],
#  [None, 'Eid-e-milad', 'Monday', '16th September'],
#  ['10', 'Gandhi Jayanti', 'Wednesday', '02nd October'],
#  ['11', 'Dussehra (Vijaya Dashmi)', 'Saturday', '12th October'],
#  ['12', 'Diwali', 'Thursday', '31st October'],
#  ['13', 'Govardhan Puja', 'Friday', '01st November'],
#  ['14', 'Guru Nanak Jayanti', 'Monday', '27th November'],
# ...
